# %% [markdown]
# # Basics of logistic regression

# %% [markdown]
# ## Import the relevant libraries

# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

#Apply a fix to the statsmodels library
#from scipy import stats
#stats.chisqprob = lambda chisq, df: stats.chi2.sf(chisq, df)
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Cómo subir un archivo CSV a Google Colab

from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-b83a7e8d-1a02-4f98-ab2a-494e7cd20057" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b83a7e8d-1a02-4f98-ab2a-494e7cd20057">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 2.01. Admittance.csv to 2.01. Admittance (2).csv
# {'2.01. Admittance.csv': b'SAT,Admitted\r\n1363,No\r\n1792,Yes\r\n1954,Yes\r\n1653,No\r\n1593,No\r\n1755,Yes\r\n1775,Yes\r\n1887,Yes\r\n1893,Yes\r\n1580,No\r\n1857,Yes\r\n1880,Yes\r\n1664,Yes\r\n1364,No\r\n1693,No\r\n1850,Yes\r\n1633,No\r\n1634,No\r\n1636,Yes\r\n1855,Yes\r\n1987,Yes\r\n1997,Yes\r\n1422,No\r\n1508,No\r\n1720,Yes\r\n1879,Yes\r\n1634,Yes\r\n1802,Yes\r\n1849,Yes\r\n1764,Yes\r\n1460,No\r\n1675,Yes\r\n1656,No\r\n2020,Yes\r\n1850,Yes\r\n1865,Yes\r\n1664,No\r\n1872,Yes\r\n1654,No\r\n1393,No\r\n1587,No\r\n1631,Yes\r\n1931,Yes\r\n1370,No\r\n1810,Yes\r\n1414,No\r\n1761,Yes\r\n1477,No\r\n1486,No\r\n1561,No\r\n1549,No\r\n2050,Yes\r\n1697,No\r\n1543,No\r\n1934,Yes\r\n1385,No\r\n1670,No\r\n1735,Yes\r\n1634,No\r\n1777,Yes\r\n1550,No\r\n1715,Yes\r\n1925,Yes\r\n1842,Yes\r\n1786,Yes\r\n1435,No\r\n1387,No\r\n1521,No\r\n1975,Yes\r\n1435,No\r\n1714,Yes\r\n1634,Yes\r\n1464,No\r\n1794,Yes\r\n1855,Yes\r\n1953,Yes\r\n1469,No\r\n1663,Yes\r\n1907,Yes\r\n1990,Yes\r\n1542,No\r\n1808,Yes\r\n1966,Yes\r\n1679,No\r\n2021,Yes\r\n2015,Yes\r\n1473,No\r\n1979,Yes\r\n1787,Yes\r\n1687,Yes\r\n1674,No\r\n1478,No\r\n1735,Yes\r\n1720,Yes\r\n1494,No\r\n1964,Yes\r\n1843,Yes\r\n1550,No\r\n1764,Yes\r\n1712,Yes\r\n1775,Yes\r\n1531,No\r\n1781,Yes\r\n1579,No\r\n1526,No\r\n1778,Yes\r\n1769,Yes\r\n1824,Yes\r\n1481,No\r\n1464,No\r\n1591,No\r\n1666,No\r\n1455,No\r\n1934,Yes\r\n1625,No\r\n1334,No\r\n1721,Yes\r\n1475,No\r\n1662,Yes\r\n1861,Yes\r\n1936,Yes\r\n1572,No\r\n1508,No\r\n1430,No\r\n1891,Yes\r\n1550,No\r\n1741,Yes\r\n1690,No\r\n1687,Yes\r\n1730,Yes\r\n1674,Yes\r\n1475,No\r\n1962,Yes\r\n1532,No\r\n1492,No\r\n1502,No\r\n1974,Yes\r\n1607,No\r\n1412,No\r\n1557,No\r\n1821,Yes\r\n1760,Yes\r\n1685,Yes\r\n1773,Yes\r\n1826,Yes\r\n1565,No\r\n1510,No\r\n1374,No\r\n1402,No\r\n1702,Yes\r\n1956,Yes\r\n1933,Yes\r\n1832,Yes\r\n1893,Yes\r\n1831,Yes\r\n1487,No\r\n2041,Yes\r\n1850,Yes\r\n1555,No\r\n2020,Yes\r\n1593,No\r\n1934,Yes\r\n1808,Yes\r\n1722,Yes\r\n1750,Yes\r\n1555,No\r\n1524,No\r\n1461,No\r\n'}

# %% [markdown]
# ## Load the data

# %%
raw_data = pd.read_csv('2.01. Admittance.csv')

# %%
data = raw_data.copy()
data['Admitted'] = data['Admitted'].map({'Yes':1,'No':0})
data
# Out:
#       SAT  Admitted
# 0    1363         0
# 1    1792         1
# 2    1954         1
# 3    1653         0
# 4    1593         0
# ..    ...       ...
# 163  1722         1
# 164  1750         1
# 165  1555         0
# 166  1524         0
# 167  1461         0
#
# [168 rows x 2 columns]

# %% [markdown]
# ## Declare the dependent and the independent variables

# %%
y = data['Admitted']
x1 = data['SAT']

# %% [markdown]
# ## Regression

# %%
x = sm.add_constant(x1)
reg_log = sm.Logit(y,x)
results_log = reg_log.fit()
# Out:
# Optimization terminated successfully.
#          Current function value: 0.137766
#          Iterations 10

# %% [markdown]
# ## Summary

# %%
results_log.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:               Admitted   No. Observations:                  168
# Model:                          Logit   Df Residuals:                      166
# Method:                           MLE   Df Model:                            1
# Date:                Sun, 18 Jul 2021   Pseudo R-squ.:                  0.7992
# Time:                        17:26:58   Log-Likelihood:                -23.145
# converged:                       True   LL-Null:                       -115.26
# Covariance Type:            nonrobust   LLR p-value:                 5.805e-42
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        -69.9128     15.737     -4.443      0.000    -100.756     -39.070
# SAT            0.0420      0.009      4.454      0.000       0.024       0.060
# ==============================================================================
#
# Possibly complete quasi-separation: A fraction 0.27 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.
# """
